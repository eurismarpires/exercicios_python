# %%
import scipy.io.wavfile as wav
import matplotlib.pyplot as plt

# %%
rate, data = wav.read('a2002011001-e02-16kHz.wav')

# %%
plt.plot(data)
# Out:
# [<matplotlib.lines.Line2D at 0x7feb6c34f4a8>,
#  <matplotlib.lines.Line2D at 0x7feb6c34f668>]

# %%
# http://www.music.helsinki.fi/tmt/opetus/uusmedia/esim/index-e.html

# %%
rate
# Out:
# 16000

# %%
a = data[:1000]

# %%
plt.plot(a)
# Out:
# [<matplotlib.lines.Line2D at 0x7feb6d0580b8>,
#  <matplotlib.lines.Line2D at 0x7feb6d058278>]

# %%
plt.plot(a[:100])
# Out:
# [<matplotlib.lines.Line2D at 0x7feb6d00f390>,
#  <matplotlib.lines.Line2D at 0x7feb6d00f550>]

# %%
plt.plot(a[200:400])
# Out:
# [<matplotlib.lines.Line2D at 0x7feb59774e48>,
#  <matplotlib.lines.Line2D at 0x7feb59772048>]

# %%
a[200:400]
# Out:
# array([[ -49,   24],
#        [ -39,   24],
#        [ -18,   21],
#        [  -6,   22],
#        [  -7,   24],
#        [ -11,   29],
#        [ -15,   33],
#        [ -17,   31],
#        [ -18,   24],
#        [ -22,   13],
#        [ -29,    8],
#        [ -34,   19],
#        [ -29,   35],
#        [ -25,   46],
#        [ -23,   52],
#        [ -16,   51],
#        [  -7,   45],
#        [   4,   40],
#        [  10,   36],
#        [   8,   37],
#        [   4,   42],
#        [   1,   51],
#        [  -1,   53],
#        [   3,   46],
#        [  12,   38],
#        [  19,   37],
#        [  25,   42],
#        [  31,   47],
#        [  31,   54],
#        [  26,   51],
#        [  24,   40],
#        [  19,   33],
#        [  17,   31],
#        [  25,   27],
#        [  32,   24],
#        [  37,   28],
#        [  38,   35],
#        [  32,   34],
#        [  22,   24],
#        [  11,   14],
#        [  10,    8],
#        [  28,   15],
#        [  44,   27],
#        [  50,   29],
#        [  56,   24],
#        [  59,   17],
#        [  55,    9],
#        [  49,    5],
#        [  41,    3],
#        [  38,    7],
#        [  44,   13],
#        [  58,   23],
#        [  67,   39],
#        [  67,   47],
#        [  61,   44],
#        [  56,   37],
#        [  64,   30],
#        [  73,   24],
#        [  68,   21],
#        [  53,   28],
#        [  40,   41],
#        [  36,   46],
#        [  36,   47],
#        [  31,   50],
#        [  22,   46],
#        [  21,   42],
#        [  26,   46],
#        [  27,   51],
#        [  22,   53],
#        [   3,   50],
#        [ -19,   44],
#        [ -21,   33],
#        [ -17,   22],
#        [ -13,   15],
#        [  -1,   11],
#        [  -2,   15],
#        [ -16,   21],
#        [ -24,   27],
#        [ -26,   31],
#        [ -24,   33],
#        [ -27,   41],
#        [ -29,   54],
#        [ -24,   59],
#        [ -14,   55],
#        [ -10,   47],
#        [ -18,   37],
#        [ -22,   25],
#        [ -15,   15],
#        [  -7,   18],
#        [   1,   24],
#        [   6,   32],
#        [   3,   36],
#        [   5,   30],
#        [   6,   30],
#        [  -1,   24],
#        [  -7,   12],
#        [ -10,   12],
#        [ -18,   11],
#        [ -19,   12],
#        [ -11,   26],
#        [  -6,   34],
#        [  -5,   28],
#        [  -7,   14],
#        [ -18,    5],
#        [ -37,    5],
#        [ -50,   13],
#        [ -48,   19],
#        [ -40,   17],
#        [ -28,   12],
#        [ -12,   15],
#        [   1,   19],
#        [   2,   22],
#        [  -8,   21],
#        [ -13,   17],
#        [ -23,   18],
#        [ -38,   24],
#        [ -42,   29],
#        [ -36,   31],
#        [ -26,   34],
#        [ -19,   37],
#        [ -19,   36],
#        [ -14,   46],
#        [ -10,   62],
#        [ -17,   66],
#        [ -25,   65],
#        [ -36,   63],
#        [ -56,   58],
#        [ -68,   59],
#        [ -65,   61],
#        [ -61,   56],
#        [ -59,   47],
#        [ -59,   42],
#        [ -68,   46],
#        [ -73,   54],
#        [ -76,   56],
#        [ -87,   53],
#        [ -96,   47],
#        [-101,   36],
#        [ -96,   27],
#        [ -70,   22],
#        [ -44,   17],
#        [ -39,   19],
#        [ -45,   32],
#        [ -50,   41],
#        [ -47,   39],
#        [ -43,   30],
#        [ -44,   16],
#        [ -50,    5],
#        [ -53,   -3],
#        [ -45,   -6],
#        [ -27,   -2],
#        [ -12,   -5],
#        [  -7,   -7],
#        [  -4,    0],
#        [   5,   -3],
#        [  14,  -15],
#        [  11,  -27],
#        [   0,  -43],
#        [ -12,  -49],
#        [ -19,  -39],
#        [ -17,  -25],
#        [  -8,  -15],
#        [   1,  -22],
#        [   5,  -32],
#        [  11,  -37],
#        [  16,  -35],
#        [  11,  -22],
#        [   7,  -15],
#        [  -4,  -20],
#        [ -17,  -24],
#        [  -7,  -24],
#        [   7,  -20],
#        [  21,  -18],
#        [  35,  -17],
#        [  27,   -4],
#        [  19,   10],
#        [  21,    9],
#        [  26,   -2],
#        [  27,  -14],
#        [  23,  -18],
#        [  21,  -12],
#        [  16,    3],
#        [   8,   16],
#        [  -1,   18],
#        [  -4,   18],
#        [  -5,   23],
#        [ -18,   26],
#        [ -32,   17],
#        [ -41,    6],
#        [ -51,    4],
#        [ -57,    6],
#        [ -51,   21],
#        [ -44,   36],
#        [ -46,   33],
#        [ -49,   27],
#        [ -39,   25],
#        [ -25,   28],
#        [ -16,   30],
#        [ -18,   32],
#        [ -28,   34]], dtype=int16)
