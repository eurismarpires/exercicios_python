# %%
from pylab import *
from PIL import Image

# %%
im = array(Image.open('papagaio.jpg'))

# %%
imshow(im)

# %%
x = [100,100,400,400]
y = [200,500,200,500]

# %%
# plot the points with red star-markers
plot(x,y,'r*')

# %%
# line plot connecting the first two points
plot(x[:2],y[:2])

# %%
title('Plotting: "papagaio.jpg"')

# %%
show()
