# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/eurismarpires/exercicios_python/blob/master/exibir_imagens.ipynb)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
# !wget https://matplotlib.org/_images/stinkbug.png
img=mpimg.imread('stinkbug.png')  
imgplot = plt.imshow(img)
# Out:
# --2018-05-16 12:56:31--  https://matplotlib.org/_images/stinkbug.png
# Resolving matplotlib.org (matplotlib.org)... 104.25.1.116, 104.25.2.116, 2400:cb00:2048:1::6819:274, ...
# Connecting to matplotlib.org (matplotlib.org)|104.25.1.116|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60375 (59K) [image/png]
# Saving to: ‘stinkbug.png.2’
#
# stinkbug.png.2      100%[===================>]  58.96K  --.-KB/s    in 0.01s
#
# 2018-05-16 12:56:31 (4.13 MB/s) - ‘stinkbug.png.2’ saved [60375/60375]

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
array = np.random.rand(28,28,3)
imgplot = plt.imshow(array)
