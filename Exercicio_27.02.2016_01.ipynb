# %% [markdown]
# # Expressões Lâmbdas

# %%
def size_each(words):
    return [len(w) for w in words]

# %%
words = ['look', 'so', 'car', 'ice', 'melted']

# %%
size_each(words)
# Out:
# [4, 2, 3, 3, 6]

# %%
size_each = lambda words: [len(w) for w in words]

# %%
size_each(words)
# Out:
# [4, 2, 3, 3, 6]

# %%
teste = actfunc=lambda x: x

# %%
a = 'arroz'

# %%
teste(a)
# Out:
# 'arroz'

# %%
b = [3,4,5]

# %%
teste(b)
# Out:
# [3, 4, 5]

# %% [markdown]
# # Gráficos

# %%
x = [100,100,400,400]
y = [200,500,200,500]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(x,y)

# %% [markdown]
# # Imagens

# %%
from PIL import Image

# %%
pil_im = Image.open('papagaio.jpg')

# %%
pil_im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x266 at 0x60B0DD8>
