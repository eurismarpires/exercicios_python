# %%
from music21 import *
from IPython.display import *

# %%
f = "http://www.classicalguitarmidi.com/subivic/Tarrega_Endecha.mid"
c = converter.parse(f)

# %%
Image(filename=c.write('lily.png'))

# %%
c.show('text')
# Out:
# {0.0} <music21.stream.Part 0x7fb6363c84e0>
#     {0.0} <music21.instrument.Lute Lute>
#     {0.0} <music21.tempo.MetronomeMark Quarter=100.0>
#     {0.0} <music21.meter.TimeSignature 2/4>
#     {0.0} <music21.stream.Voice 0x7fb63632c198>
#         {0.0} <music21.note.Note A>
#         {0.5} <music21.note.Note D>
#         {1.0} <music21.note.Note A>
#         {1.5} <music21.note.Note G>
#         {2.0} <music21.note.Note F>
#         {2.5} <music21.chord.Chord D2 E4>
#         {3.0} <music21.chord.Chord F3 A3 D4>
#         {4.0} <music21.note.Note D>
#         {4.5} <music21.note.Note E>
#         {5.0} <music21.note.Note F#>
#         {5.5} <music21.note.Note G>
#         {6.0} <music21.note.Note A>
#         {6.5} <music21.chord.Chord G2 C5>
#         {7.0} <music21.chord.Chord D4 E4 B-4>
#         {8.0} <music21.note.Note A>
#         {8.5} <music21.note.Note G>
#         {9.0} <music21.note.Note F>
#         {9.5} <music21.note.Note E>
#         {10.0} <music21.note.Note D>
# ...
